# %%
# !pip install pybaseball
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.1/426.1 kB 5.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.4/106.4 kB 17.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 27.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.3/34.3 MB 21.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.7/432.7 kB 23.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 20.3 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 382.6/382.6 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 4.5 MB/s eta 0:00:00
# ...

# %%
import requests
import pandas as pd

# %%
from pybaseball import league_batting_stats

# %%
batter_df = league_batting_stats.batting_stats_bref()
batter_df
# Out:
#                         Name  Age  #days     Lev          Tm    G   PA   AB  \
# 1                  CJ Abrams   24     41  Maj-NL  Washington  144  635  580
# 2               Wilyer Abreu   26     37  Maj-AL      Boston  116  422  378
# 3              Maximo Acosta   22     55  Maj-NL       Miami   19   61   54
# 4     Luisangel Acu\xc3\xb1a   23     42  Maj-NL    New York   95  193  175
# 5    Ronald Acu\xc3\xb1a Jr.   27     41  Maj-NL     Atlanta   95  412  338
# ..                       ...  ...    ...     ...         ...  ...  ...  ...
# 697               Nick Yorke   23     41  Maj-NL  Pittsburgh   22   72   69
# 698         Masataka Yoshida   31     37  Maj-AL      Boston   58  212  195
# 699               Cole Young   21     41  Maj-AL     Seattle   77  257  223
# 700              Jacob Young   25     41  Maj-NL  Washington  120  364  324
# 701              Jared Young   29     41  Maj-NL    New York   22   47   43
#
# ...

# %%
batter_df.to_csv('../data/raw/batter_stats.csv', index=False, encoding='utf-8')

# %%
batter_df = pd.read_csv('../data/raw/batter_stats.csv', encoding='utf-8')

# %%
batter_df
# Out:
#                         Name  Age  #days     Lev          Tm    G   PA   AB  \
# 0                  CJ Abrams   24     41  Maj-NL  Washington  144  635  580
# 1               Wilyer Abreu   26     37  Maj-AL      Boston  116  422  378
# 2              Maximo Acosta   22     55  Maj-NL       Miami   19   61   54
# 3     Luisangel Acu\xc3\xb1a   23     42  Maj-NL    New York   95  193  175
# 4    Ronald Acu\xc3\xb1a Jr.   27     41  Maj-NL     Atlanta   95  412  338
# ..                       ...  ...    ...     ...         ...  ...  ...  ...
# 670               Nick Yorke   23     41  Maj-NL  Pittsburgh   22   72   69
# 671         Masataka Yoshida   31     37  Maj-AL      Boston   58  212  195
# 672               Cole Young   21     41  Maj-AL     Seattle   77  257  223
# 673              Jacob Young   25     41  Maj-NL  Washington  120  364  324
# 674              Jared Young   29     41  Maj-NL    New York   22   47   43
#
# ...
