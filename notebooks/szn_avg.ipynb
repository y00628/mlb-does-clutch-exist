# %%
# !pip install pybaseball
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 426.1/426.1 kB 5.2 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.4/106.4 kB 17.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.7/64.7 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 27.1 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.3/34.3 MB 21.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 432.7/432.7 kB 23.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.9/20.9 MB 20.3 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 382.6/382.6 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 4.5 MB/s eta 0:00:00
# ...

# %%
import requests
import pandas as pd

# %%
# pip install pybaseball
from pybaseball import batting_stats, pitching_stats

# 2025 batters with pLI (and clutch/WPA family)
bat = batting_stats(2025)
bat_li = bat[["Name","Team","PA","pLI","Clutch","WPA","-WPA","+WPA"]]
print(bat_li.head())

# 2025 pitchers with the full LI set
pit = pitching_stats(2025)
pit_li = pit[["Name","Team","IP","pLI","gmLI","inLI","exLI","WPA","RE24","REW"]]
print(pit_li.head())
# Out:
#                Name Team   PA   pLI  Clutch   WPA   -WPA   +WPA
# 0       Aaron Judge  NYY  679  0.90   -1.50  5.61  -8.63  14.24
# 3       Cal Raleigh  SEA  705  1.03   -0.91  3.84 -11.43  15.27
# 22   Bobby Witt Jr.  KCR  687  1.00   -0.08  3.37 -11.21  14.58
# 1     Shohei Ohtani  LAD  727  0.96    0.25  5.89 -10.53  16.41
# 8   Geraldo Perdomo  ARI  720  0.98    0.47  3.45 -10.96  14.41
#                   Name Team     IP   pLI  gmLI  inLI  exLI   WPA   RE24   REW
# 1         Tarik Skubal  DET  195.1  0.95  0.87  0.94  1.23  3.97  43.61  4.50
# 0          Paul Skenes  PIT  187.2  0.98  0.87  0.98  1.07  5.18  52.52  5.32
# 4   Cristopher Sanchez  PHI  202.0  1.03  0.87  0.97  1.20  4.63  46.69  4.70
# 5      Garrett Crochet  BOS  205.1  1.00  0.87  0.97  1.12  4.93  44.74  4.54
# 15          Logan Webb  SFG  207.0  1.04  0.87  0.92  0.94  1.67  19.48  1.99

# %%
bat_li
# Out:
#                  Name   Team   PA   pLI  Clutch   WPA   -WPA   +WPA
# 0         Aaron Judge    NYY  679  0.90   -1.50  5.61  -8.63  14.24
# 3         Cal Raleigh    SEA  705  1.03   -0.91  3.84 -11.43  15.27
# 22     Bobby Witt Jr.    KCR  687  1.00   -0.08  3.37 -11.21  14.58
# 1       Shohei Ohtani    LAD  727  0.96    0.25  5.89 -10.53  16.41
# 8     Geraldo Perdomo    ARI  720  0.98    0.47  3.45 -10.96  14.41
# ..                ...    ...  ...   ...     ...   ...    ...    ...
# 113  Andrew McCutchen    PIT  551  1.00   -0.60 -1.61 -10.18   8.57
# 123    Nathaniel Lowe  - - -  609  1.01    0.77  0.12 -10.53  10.65
# 124    Jonathan India    KCR  567  0.96    0.94 -0.88 -10.13   9.25
# 135      Eric Wagaman    MIA  514  0.98   -1.40 -2.66 -10.24   7.58
# 125  Nick Castellanos    PHI  589  1.04   -1.51 -2.54 -11.72   9.18
#
# [145 rows x 8 columns]

# %%
pit_li
# Out:
#                   Name   Team     IP   pLI  gmLI  inLI  exLI   WPA   RE24  \
# 1         Tarik Skubal    DET  195.1  0.95  0.87  0.94  1.23  3.97  43.61
# 0          Paul Skenes    PIT  187.2  0.98  0.87  0.98  1.07  5.18  52.52
# 4   Cristopher Sanchez    PHI  202.0  1.03  0.87  0.97  1.20  4.63  46.69
# 5      Garrett Crochet    BOS  205.1  1.00  0.87  0.97  1.12  4.93  44.74
# 15          Logan Webb    SFG  207.0  1.04  0.87  0.92  0.94  1.67  19.48
# 27       Jesus Luzardo    PHI  183.2  0.96  0.87  0.91  1.27  1.70  10.12
# 3   Yoshinobu Yamamoto    LAD  173.2  0.96  0.88  0.95  1.02  4.01  33.14
# 7            Max Fried    NYY  195.1  0.93  0.88  0.87  1.04  2.06  24.52
# 2         Hunter Brown    HOU  185.1  0.97  0.88  0.93  1.11  3.43  34.90
# 21       Kevin Gausman    TOR  193.0  0.96  0.88  0.91  0.97  1.51  16.55
# 23      Framber Valdez    HOU  192.0  0.98  0.87  0.89  1.09  1.49  10.87
# 8        Andrew Abbott    CIN  166.1  1.02  0.88  0.95  1.12  2.94  28.03
# ...
